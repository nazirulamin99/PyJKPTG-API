# %%
# %pip install numpy pandas
# Out:
# ...
#   Using cached pandas-3.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (79 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 1.1 MB/s  0:00:04 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 1.0 MB/s  0:00:09m0:00:0100:010m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import duckdb
import numpy as np
import pandas as pd

# %%
qry = """
    SELECT *
    FROM './data/Shiplist-20260112.parquet'
"""

# qry = """
# SELECT *
# FROM './data/License-20260112.parquet'
# """

# %%
df = duckdb.sql(qry).df()

# %%
df
# Out:
#     fileNo                    company  \
# 0   SK 561  Teratai Senandung Sdn Bhd
# 1   SK 538         Eco Silex Sdn Bhd
# 2   SK 552  Zeemus Specialist Sdn Bhd
# 3   SK 552  Zeemus Specialist Sdn Bhd
# 4   SK 552  Zeemus Specialist Sdn Bhd
# 5   SK 469    C.S AWL Marines Sdn Bhd
# 6   SK 469    C.S AWL Marines Sdn Bhd
# 7   SK 469    C.S AWL Marines Sdn Bhd
# 8   SK 469    C.S AWL Marines Sdn Bhd
# 9   SK 469    C.S AWL Marines Sdn Bhd
# 10  SK 461      EKL Business Sdn Bhd
# 11  SK 461      EKL Business Sdn Bhd
# 12  SK 461      EKL Business Sdn Bhd
# 13  SK 461      EKL Business Sdn Bhd
# 14  SK 461      EKL Business Sdn Bhd
# 15  SK 461      EKL Business Sdn Bhd
# 16  SK 461      EKL Business Sdn Bhd
# 17  SK 461      EKL Business Sdn Bhd
# 18  SK 461      EKL Business Sdn Bhd
# 19  SK 461      EKL Business Sdn Bhd
# 20  SK 461      EKL Business Sdn Bhd
# 21  SK 461      EKL Business Sdn Bhd
# 22  SK 461      EKL Business Sdn Bhd
# 23  SK 461      EKL Business Sdn Bhd
# ...

# %%
import duckdb
cols = duckdb.sql("SELECT * FROM './data/Shiplist-20260112.parquet' LIMIT 0").columns
print(cols)
# Out:
# ['fileNo', 'company', 'shipName', 'shipCapacity', 'licenseNo', 'concession', 'licensePeriod', 'project', 'allowOptPeriod', 'optTime', 'royalty', 'official', 'licensePeriodStart', 'licensePeriodEnd', 'allowOptStart', 'allowOptEnd', 'optTimeStart', 'optimeEnd']

# %%
df = duckdb.sql("SELECT * FROM './data/Shiplist-20260112.parquet'").df()
print(f"Rows: {len(df)}")
print(f"\nUnique fileNo: {df['fileNo'].nunique()} -> {df['fileNo'].unique().tolist()[:5]}...")
print(f"Unique company: {df['company'].nunique()}")
print(f"Unique shipName: {df['shipName'].nunique()}")
print(f"Unique licenseNo: {df['licenseNo'].nunique()}")
print(f"Unique concession: {df['concession'].nunique()} -> {df['concession'].unique().tolist()[:5]}")
print(f"Unique project: {df['project'].nunique()} -> {df['project'].unique().tolist()[:5]}")
print(f"\nSample row:")
print(df.iloc[0].to_dict())
# Out:
# Rows: 56
#
# Unique fileNo: 12 -> ['SK 561', 'SK 538', 'SK 552', 'SK 469', 'SK 461']...
# Unique company: 12
# Unique shipName: 52
# Unique licenseNo: 12
# Unique concession: 4 -> ['Perak', 'Selangor', 'Melaka', 'Johor']
# Unique project: 20 -> ['Penambakan Seri Tanjung Pinang (Phase II)  Tanjung Tokong, Pulau Pinang.', 'Penambakan  Projek Pemuliharaan Pantai Morib, Selangor.', 'Tapak Penambakan Pantai Morib, Banting, Selangor\n', 'Proposed Contruction and Completion of Dredging and Land Reclamation Works CT10 to CT13 (Phase 1) and Associated Works at Westports, Pulau Indah, Pelabuhan Klang, Selangor.', 'Membekal Pasir Untuk Projek Penambakan di Gurney Drive dan Gurney Bay, Pulau Pinang.\n\nPenambakan Seri Tanjung Pinang (Phase 2) Development (STP2). Pulau Pinang.']
#
# Sample row:
# ...
